# %%
import ROOT
import stage0
import utils
import numpy as np
import matplotlib.pyplot as plt

# %jsroot on
# Out:
# Welcome to JupyROOT 6.30/04

# %%
chain = ROOT.TChain("rawTree")

chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_012[4-9]*") ### chunk 1
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_013[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_014[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_015[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_016[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_017[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_018[0-9]*")

chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_019[0-9]*") ### chunk 2
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_020[7-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_021[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_022[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_023[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_024[0-2]*")

chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_024[5-9]*") ### chunk 3
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_025[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_026[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_027[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_028[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_029[0-9]*")
chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_030[0-8]*")


# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0309*")

# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0310*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0311*")

### Pr 1hr
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0926*")

### Pr Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_093[6-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_094[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_095[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_096[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_097[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_098[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_099[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_100[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_101[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_102[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_103[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_104[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_105[0-1]*")

# # ### Ho Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_105[7-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_106[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_107[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_108[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_109[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_110[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_111[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_112[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_113[0-2]*")


### Gd Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_113[6-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_114[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_115[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_116[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_117[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_118[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_119[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_120[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_121[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_122[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_123[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_124[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_125[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_126[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_127[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_128[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_129[0-2]*")


# ### Er Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_129[7-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_130[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_131[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_132[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_133[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_134[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_135[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_136[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_137[0-8]*")


# ### Re Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_138[0-9]*")

### La Polarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0931*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0932*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0933*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0934*")


### Sm unpolarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0916*")


# ### Nd unpolarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0906*")

# ### Ce unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0002*")

# ### Eu unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0006*")

### Hf unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0007*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0008*")

# ### Ir unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0011*")

# ### Ba unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0016*")

# ### Pr unpolarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0018*")

# ### Tb unpolarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_139[5-9]*")
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_14[0-9]*")

# ### Tm unpolarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0913*")

# ### Yb unpolarized
# chain.Add("/Volumes/WD_BLACK/2024Mar/Ge/rawroot/rawroot_run_0908*")


# # ### Ta Polarized
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_031[3-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_032[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_033[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_034[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_035[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_036[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_037[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_038[0-9]*")

## Cd Branching Ratio
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_048[2-2]*") #test

# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_048[2-9]*") # 950 kW
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_049[0-4]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_050[3-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_051[0-9]*")

# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_052[1-9]*") # 900 kW
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_053[1-7]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_053[9-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_054[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_055[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_056[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_057[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_058[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_059[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_060[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_061[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_062[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_063[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_064[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_065[0-8]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_066[1-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_067[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_068[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_069[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_070[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_071[0-1]*")

# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0712*")


# ### Tm
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_011[6-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_012[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_013[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_014[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_015[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_016[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_017[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_018[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_019[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_020[0-8]*")

# # Pr
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_072[1-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_073[0-6]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_073[8-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_074[0-7]*")


# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_0749*")


# # ### Pr 15mm rot
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_075[1-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_076[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_077[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2024May/Ge/rawroot/rawroot_run_078[0-1]*")


# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_012[4-9]*")  ### chunk 1
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_013[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_014[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_015[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_016[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_017[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_018[0-9]*")

# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_019[0-9]*")  ### chunk 2
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_020[7-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_021[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_022[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_023[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_024[0-2]*")

# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_024[5-9]*")  ### chunk 3
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_025[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_026[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_027[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_028[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_029[0-9]*")
# chain.Add("/Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_030[0-8]*")
# Out:
# 9

# %%
ROOT.EnableImplicitMT()  # Enable multi-threading

df = ROOT.RDataFrame(chain)

# df = stage0.filter_active_channels(df)

df = stage0.define_columns(df)

# df = df.Filter("PulseHeight > 0")

# df = df.Filter("")

df.Describe().Print()
# Out:
# Dataframe from TChain rawTree in files
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0124_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0125_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0126_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0127_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0128_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0129_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0130_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0131_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0132_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0133_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0134_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0135_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0136_000.root
#   /Volumes/WD_BLACK/2023Dec/rawroot/rawroot_run_0137_000.root
# ...

# %%
# xbins = np.array(utils.get_xbins_En(0.1, 10, 21.5,100))
xbins = np.array(utils.get_xbins_En(0.1, 100, 21.5, 100))
# ybins = np.array(utils.get_xbins(8000, 2000, 10000, False, 21.5))
ybins = np.array(utils.get_xbins_Egam(8000, 10000, 4))

hEn_hEgam_model = ROOT.RDF.TH2DModel(
    "hEn_hEgam",
    "hEn_hEgam;En (eV); Egam (keV)",
    len(xbins) - 1,
    xbins,
    len(ybins) - 1,
    ybins,
)
hEn_model = ROOT.RDF.TH1DModel("hEn", "hEn; En (eV); Counts", len(xbins) - 1, xbins)
hEgam_model = ROOT.RDF.TH1DModel(
    "hEgam", "hEgam; Egam (keV); counts", len(ybins) - 1, ybins
)

# hEn_hEgam = df.Histo2D(hEn_hEgam_model,"En","Egam_rounded")
hEn_hEgam = df.Histo2D(hEn_hEgam_model, "En", "Egam")
hEn = df.Histo1D(hEn_model, "En")
hEgam = df.Histo1D(hEgam_model, "Egam")

# %%
# xbins = np.array(utils.get_xbins_En(0.5, 100, 21.5))
# # xbins1 = np.array(utils.get_xbins(200000, 0, 200000, True, 21.5))
# # print(xbins)

# hEn_model = ROOT.RDF.TH1DModel("hEn", "hEn; En (eV); Counts",  len(xbins)-1, xbins)
# # hEn_model1 = ROOT.RDF.TH1DModel("hEn", "hEn; En (eV); Counts",  len(xbins1)-1, xbins1)

# hEn = df.Histo1D(hEn_model,"En")
# # hEn1 = df.Histo1D(hEn_model1,"En")


# c = ROOT.TCanvas()

# hEn.Draw()

# # hEn.Draw("same")
# # hEn.SetLineColor(ROOT.kRed)

# # # hEn_hEgam.Draw("colz")
# # # hEn_hEgam.GetXaxis().SetRangeUser(2,10)
# # # hEn_hEgam.GetYaxis().SetRangeUser(2000,12000)
# # # c.SetLogz()
# # ROOT.gStyle.SetOptStat(0)
# c.Draw()

# %%
f = ROOT.TFile.Open("../output/2023dec/Cd_all_3D.root", "recreate")

hEn_hEgam.Write()
hEn.Write()
hEgam.Write()

f.Close()

# %%
# import ROOT
# %jsroot on

# f = ROOT.TFile.Open("2023dec_3D_Pr.root","READ")

# hEn_hEgam = f.Get("hEn_hEgam")


# x1 = hEn_hEgam.GetYaxis().FindBin(9200)
# x2 = hEn_hEgam.GetYaxis().FindBin(9500)
# hEn_hEgam_proj = hEn_hEgam.ProjectionX("projection",x1,x2)


# # hEn_hEgam.SetDirectory(0)

# c = ROOT.TCanvas()

# hEn_hEgam_proj.Draw()

# hEn_hEgam_proj.GetXaxis().SetRangeUser(1,8)

# # hEn_hEgam_proj.Rebin(2)
# # hEn_hEgam_proj.Smooth()

# hEn_hEgam_proj_bkg = hEn_hEgam_proj.ShowBackground(40,"same nocompton")
# hEn_hEgam_proj.Add(hEn_hEgam_proj_bkg,-1)


# c.Draw()
# ROOT.gROOT.GetListOfCanvases().Draw()
